# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# Load in the dataset
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Check the shape of the data
print(x_train.shape)
print(y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_train_reshape = x_train.reshape(50000, 3, 32, 32).transpose(0, 2, 3, 1).astype('uint8')

# Visualize CIFAR

figs, axes = plt.subplots(5, 5, figsize=(10, 10))
for j in range(5):
    for k in range(5):
        i = np.random.choice(range(len(x_train_reshape)))
        axes[j][k].set_axis_off()
        axes[j][k].imshow(x_train_reshape[i:i+1][0])
